# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
# !nvidia-smi
# Out:
# Sun Apr 17 06:28:58 2022
# +-----------------------------------------------------------------------------+
# | NVIDIA-SMI 460.32.03    Driver Version: 460.32.03    CUDA Version: 11.2     |
# |-------------------------------+----------------------+----------------------+
# | GPU  Name        Persistence-M| Bus-Id        Disp.A | Volatile Uncorr. ECC |
# | Fan  Temp  Perf  Pwr:Usage/Cap|         Memory-Usage | GPU-Util  Compute M. |
# |                               |                      |               MIG M. |
# |===============================+======================+======================|
# |   0  Tesla P100-PCIE...  Off  | 00000000:00:04.0 Off |                    0 |
# | N/A   32C    P0    26W / 250W |      0MiB / 16280MiB |      0%      Default |
# |                               |                      |                  N/A |
# +-------------------------------+----------------------+----------------------+
#
# ...

# %%
import torch
torch.cuda.is_available()
# Out:
# True

# %%
import tensorflow as tf
tf.test.gpu_device_name()
# Out:
# '/device:GPU:0'

# %%
# !python drive/MyDrive/Colab\ Notebooks/Person\ ReId/bagoftricks.py --name="_prid_" --validation-training --opt=24
# Out:
# ['splits_prid2011.json', 'prid_2011']
# usage: bagoftricks.py [-h]
#                       [-d {mars,ilidsvid,prid,mars_subset,mars_subset2,prid_subset,ilidsvid_subset}]
#                       [-j WORKERS] [--height HEIGHT] [--width WIDTH]
#                       [--seq-len SEQ_LEN] [--max-epoch MAX_EPOCH]
#                       [--start-epoch START_EPOCH] [--train-batch TRAIN_BATCH]
#                       [--test-batch TEST_BATCH] [--lr LR]
#                       [--stepsize STEPSIZE] [--gamma GAMMA]
#                       [--weight-decay WEIGHT_DECAY] [--margin MARGIN]
#                       [--num-instances NUM_INSTANCES] [--use-OSMCAA]
#                       [--cl-centers] [-a ARCH] [--pool {avg,max}]
#                       [--print-freq PRINT_FREQ] [--seed SEED]
#                       [--pretrained-model PRETRAINED_MODEL] [--evaluate]
#                       [--save-dir SAVE_DIR] [--epochs-eval EPOCHS_EVAL]
#                       [--name NAME] [--validation-training]
# ...

# %%
# !python drive/MyDrive/Colab\ Notebooks/Person\ ReId/bagoftricks.py --name="_prid_" --validation-training --dataset="prid" --arch=ResNet50ta_bt --cl-centers --use-OSMCAA --pretrained-model='mars' --resume-training
# Out:
# ['splits_prid2011.json', 'prid_2011']
# prid
# # train identites: 89, # test identites 89
# => PRID-2011 loaded
# Dataset statistics:
#   ------------------------------
#   subset   | # ids | # tracklets
#   ------------------------------
#   train    |    89 |      178
#   query    |    89 |       89
#   gallery  |    89 |       89
#   ------------------------------
#   total    |   178 |      356
#   number of images per tracklet: 28 ~ 675, average 108.1
#   ------------------------------
# /usr/local/lib/python3.7/dist-packages/torchvision/transforms/transforms.py:288: UserWarning: Argument interpolation should be of type InterpolationMode instead of int. Please, use InterpolationMode enum.
#   "Argument interpolation should be of type InterpolationMode instead of int. "
# ...

# %%
# !nvcc --version
# Out:
# nvcc: NVIDIA (R) Cuda compiler driver
# Copyright (c) 2005-2020 NVIDIA Corporation
# Built on Mon_Oct_12_20:09:46_PDT_2020
# Cuda compilation tools, release 11.1, V11.1.105
# Build cuda_11.1.TC455_06.29190527_0

# %%
# !python drive/MyDrive/Colab\ Notebooks/Person\ ReId/bagoftricks.py --name="_prid_" --validation-training --dataset="prid" --arch=ResNet50ta_bt --cl-centers --use-OSMCAA --pretrained-model='mars' --test-batch
# Out:
# usage: bagoftricks.py [-h]
#                       [-d {mars,ilidsvid,prid,mars_subset,mars_subset2,prid_subset,ilidsvid_subset}]
#                       [-j WORKERS] [--height HEIGHT] [--width WIDTH]
#                       [--seq-len SEQ_LEN] [--max-epoch MAX_EPOCH]
#                       [--start-epoch START_EPOCH] [--train-batch TRAIN_BATCH]
#                       [--test-batch TEST_BATCH] [--lr LR]
#                       [--stepsize STEPSIZE] [--gamma GAMMA]
#                       [--weight-decay WEIGHT_DECAY] [--margin MARGIN]
#                       [--num-instances NUM_INSTANCES] [--use-OSMCAA]
#                       [--cl-centers] [-a ARCH] [--pool {avg,max}]
#                       [--print-freq PRINT_FREQ] [--seed SEED]
#                       [--pretrained-model PRETRAINED_MODEL] [--evaluate]
#                       [--save-dir SAVE_DIR] [--epochs-eval EPOCHS_EVAL]
#                       [--name NAME] [--validation-training]
# ...
