# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).

# %%
# !nvidia-smi
# Out:
# Mon Apr 18 08:17:23 2022
# +-----------------------------------------------------------------------------+
# | NVIDIA-SMI 460.32.03    Driver Version: 460.32.03    CUDA Version: 11.2     |
# |-------------------------------+----------------------+----------------------+
# | GPU  Name        Persistence-M| Bus-Id        Disp.A | Volatile Uncorr. ECC |
# | Fan  Temp  Perf  Pwr:Usage/Cap|         Memory-Usage | GPU-Util  Compute M. |
# |                               |                      |               MIG M. |
# |===============================+======================+======================|
# |   0  Tesla T4            Off  | 00000000:00:04.0 Off |                    0 |
# | N/A   37C    P8     9W /  70W |      0MiB / 15109MiB |      0%      Default |
# |                               |                      |                  N/A |
# +-------------------------------+----------------------+----------------------+
#
# ...

# %%
import torch
torch.cuda.is_available()
# Out:
# True

# %%
import tensorflow as tf
tf.test.gpu_device_name()
# Out:
# '/device:GPU:0'

# %%
# !python drive/MyDrive/Colab\ Notebooks/Person\ ReId/bagoftricks.py --pretrained-model="/beegfs/pp1953/ResNet50ta_bt_mars_cl_centers__8__checkpoint_ep181.pth.tar" -d="prid" --name="_prid_CL_CENTERS_" --validation-training --cl-centers --use-OSMCAA --evaluate --max-epoch=200 >> drive/MyDrive/Colab\ Notebooks/Person\ ReId/output/prid_output.out
# Out:
# /usr/local/lib/python3.7/dist-packages/torchvision/transforms/transforms.py:288: UserWarning: Argument interpolation should be of type InterpolationMode instead of int. Please, use InterpolationMode enum.
#   "Argument interpolation should be of type InterpolationMode instead of int. "
# Downloading: "https://download.pytorch.org/models/resnet50-0676ba61.pth" to /root/.cache/torch/hub/checkpoints/resnet50-0676ba61.pth
# 100% 97.8M/97.8M [00:00<00:00, 304MB/s]
# /content/drive/MyDrive/Colab Notebooks/Person ReId/loss/loss.py:166: UserWarning: This overload of addmm_ is deprecated:
# 	addmm_(Number beta, Number alpha, Tensor mat1, Tensor mat2)
# Consider using one of the following signatures instead:
# 	addmm_(Tensor mat1, Tensor mat2, *, Number beta, Number alpha) (Triggered internally at  ../torch/csrc/utils/python_arg_parser.cpp:1050.)
#   distmat.addmm_(1, -2, x, self.centers.t())
# Traceback (most recent call last):
# ...

# %%
print('hello')

# %%
# !python drive/MyDrive/Colab\ Notebooks/Person\ ReId/bagoftricks.py --pretrained-model="/beegfs/pp1953/ResNet50ta_bt_mars_cl_centers__8__checkpoint_ep181.pth.tar" -d="prid" --name="_prid_CL_CENTERS_" --validation-training --cl-centers --use-OSMCAA --evaluate --max-epoch=200 >> drive/MyDrive/Colab\ Notebooks/Person\ ReId/output/prid_output.out
# Out:
# /usr/local/lib/python3.7/dist-packages/torchvision/transforms/transforms.py:288: UserWarning: Argument interpolation should be of type InterpolationMode instead of int. Please, use InterpolationMode enum.
#   "Argument interpolation should be of type InterpolationMode instead of int. "
# /content/drive/MyDrive/Colab Notebooks/Person ReId/loss/loss.py:166: UserWarning: This overload of addmm_ is deprecated:
# 	addmm_(Number beta, Number alpha, Tensor mat1, Tensor mat2)
# Consider using one of the following signatures instead:
# 	addmm_(Tensor mat1, Tensor mat2, *, Number beta, Number alpha) (Triggered internally at  ../torch/csrc/utils/python_arg_parser.cpp:1050.)
#   distmat.addmm_(1, -2, x, self.centers.t())
# drive/MyDrive/Colab Notebooks/Person ReId/bagoftricks.py:260: UserWarning: volatile was removed and now has no effect. Use `with torch.no_grad():` instead.
#   imgs = Variable(imgs, volatile=True)
# ...

# %%
# !python drive/MyDrive/Colab\ Notebooks/Person\ ReId/bagoftricks.py --name="_prid_" --validation-training --dataset="prid" --arch=ResNet50tp >> drive/MyDrive/Colab\ Notebooks/Person\ ReId/output/prid_output_tp.out
# Out:
# /usr/local/lib/python3.7/dist-packages/torchvision/transforms/transforms.py:288: UserWarning: Argument interpolation should be of type InterpolationMode instead of int. Please, use InterpolationMode enum.
#   "Argument interpolation should be of type InterpolationMode instead of int. "
# /content/drive/MyDrive/Colab Notebooks/Person ReId/loss/loss.py:166: UserWarning: This overload of addmm_ is deprecated:
# 	addmm_(Number beta, Number alpha, Tensor mat1, Tensor mat2)
# Consider using one of the following signatures instead:
# 	addmm_(Tensor mat1, Tensor mat2, *, Number beta, Number alpha) (Triggered internally at  ../torch/csrc/utils/python_arg_parser.cpp:1050.)
#   distmat.addmm_(1, -2, x, self.centers.t())
# drive/MyDrive/Colab Notebooks/Person ReId/bagoftricks.py:260: UserWarning: volatile was removed and now has no effect. Use `with torch.no_grad():` instead.
#   imgs = Variable(imgs, volatile=True)
# ...

# %%
# !python drive/MyDrive/Colab\ Notebooks/Person\ ReId/bagoftricks.py --dataset="prid" --arch=ResNet50tp
# Out:
# # train identites: 89, # test identites 89
# => PRID-2011 loaded
# Dataset statistics:
#   ------------------------------
#   subset   | # ids | # tracklets
#   ------------------------------
#   train    |    89 |      178
#   query    |    89 |       89
#   gallery  |    89 |       89
#   ------------------------------
#   total    |   178 |      356
#   number of images per tracklet: 28 ~ 675, average 108.1
#   ------------------------------
# /usr/local/lib/python3.7/dist-packages/torchvision/transforms/transforms.py:288: UserWarning: Argument interpolation should be of type InterpolationMode instead of int. Please, use InterpolationMode enum.
#   "Argument interpolation should be of type InterpolationMode instead of int. "
# USING PRID CONFIG
# Downloading: "https://download.pytorch.org/models/resnet50-0676ba61.pth" to /root/.cache/torch/hub/checkpoints/resnet50-0676ba61.pth
# 100% 97.8M/97.8M [00:00<00:00, 305MB/s]
# Model size: 75.07565M
# ResNet50ta_bt_bot_
# ...
