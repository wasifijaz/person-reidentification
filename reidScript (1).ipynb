# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).

# %%
# !python drive/MyDrive/Colab\ Notebooks/Person\ ReId/bagoftricks.py --dataset=prid --arch=resnet50ta --cl-centers --use-OSMCAA
# Out:
# ['splits_prid2011.json', 'prid_2011']
# prid
# # train identites: 89, # test identites 89
# => PRID-2011 loaded
# Dataset statistics:
#   ------------------------------
#   subset   | # ids | # tracklets
#   ------------------------------
#   train    |    89 |      178
#   query    |    89 |       89
#   gallery  |    89 |       89
#   ------------------------------
#   total    |   178 |      356
#   number of images per tracklet: 28 ~ 675, average 108.1
#   ------------------------------
# /usr/local/lib/python3.7/dist-packages/torchvision/transforms/transforms.py:288: UserWarning: Argument interpolation should be of type InterpolationMode instead of int. Please, use InterpolationMode enum.
#   "Argument interpolation should be of type InterpolationMode instead of int. "
# ...

# %%
import os

arr = os.listdir("drive/MyDrive/Colab Notebooks/Person ReId/datasets/prid2011/")
print(arr)
# Out:
# ['splits_prid2011.json', 'prid_2011']

# %%
# !nvidia-smi
# Out:
# Sat Apr 16 19:09:45 2022
# +-----------------------------------------------------------------------------+
# | NVIDIA-SMI 460.32.03    Driver Version: 460.32.03    CUDA Version: 11.2     |
# |-------------------------------+----------------------+----------------------+
# | GPU  Name        Persistence-M| Bus-Id        Disp.A | Volatile Uncorr. ECC |
# | Fan  Temp  Perf  Pwr:Usage/Cap|         Memory-Usage | GPU-Util  Compute M. |
# |                               |                      |               MIG M. |
# |===============================+======================+======================|
# |   0  Tesla T4            Off  | 00000000:00:04.0 Off |                    0 |
# | N/A   47C    P8    10W /  70W |      0MiB / 15109MiB |      0%      Default |
# |                               |                      |                  N/A |
# +-------------------------------+----------------------+----------------------+
#
# ...

# %%
import torch
torch.cuda.is_available()
# Out:
# True

# %%
import tensorflow as tf
tf.test.gpu_device_name()
# Out:
# '/device:GPU:0'
