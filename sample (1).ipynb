# %%
# !python drive/MyDrive/Colab\ Notebooks/Person\ ReId/hyper_supervise_validation.py --dataset="prid_subset" >> drive/MyDrive/Colab\ Notebooks/Person\ ReId/output/prid_diff_val_map.out
# Out:
# [INFO 04-17 08:05:48] ax.service.utils.instantiation: Inferred value type of ParameterType.FLOAT for parameter sigma. If that is not the expected value type, you can explicity specify 'value_type' ('int', 'float', 'bool' or 'str') in parameter dict.
# [INFO 04-17 08:05:48] ax.service.utils.instantiation: Inferred value type of ParameterType.FLOAT for parameter alpha. If that is not the expected value type, you can explicity specify 'value_type' ('int', 'float', 'bool' or 'str') in parameter dict.
# [INFO 04-17 08:05:48] ax.service.utils.instantiation: Inferred value type of ParameterType.FLOAT for parameter l. If that is not the expected value type, you can explicity specify 'value_type' ('int', 'float', 'bool' or 'str') in parameter dict.
# ...

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).

# %%
# !python drive/MyDrive/Colab\ Notebooks/Person\ ReId/config_trainer.py --focus=map --dataset=prid --opt='27' --name=_prid_cl_centers_ --cl-centers >>  drive/MyDrive/Colab\ Notebooks/Person\ ReId/output/prid_cl_centers_$chikka.out
# Out:
# /usr/local/lib/python3.7/dist-packages/torchvision/transforms/transforms.py:288: UserWarning: Argument interpolation should be of type InterpolationMode instead of int. Please, use InterpolationMode enum.
#   "Argument interpolation should be of type InterpolationMode instead of int. "
# Traceback (most recent call last):
#   File "drive/MyDrive/Colab Notebooks/Person ReId/config_trainer.py", line 152, in <module>
#     abc = config.get(27,'sigma')
#   File "/usr/lib/python3.7/configparser.py", line 780, in get
#     d = self._unify_values(section, vars)
#   File "/usr/lib/python3.7/configparser.py", line 1146, in _unify_values
#     raise NoSectionError(section) from None
# configparser.NoSectionError: No section: 27
